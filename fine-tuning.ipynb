# %%
# !conda info
# Out:
#      active environment : trainings
#     active env location : /Users/rayanjoseph/anaconda3/envs/trainings
#             shell level : 1
#        user config file : /Users/rayanjoseph/.condarc
#  populated config files : /Users/rayanjoseph/.condarc
#           conda version : 23.7.4
#     conda-build version : 3.26.1
#          python version : 3.11.5.final.0
#        virtual packages : __archspec=1=arm64
#                           __osx=14.0=0
#                           __unix=0=0
#        base environment : /Users/rayanjoseph/anaconda3  (writable)
#       conda av data dir : /Users/rayanjoseph/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Users/rayanjoseph/anaconda3/pkgs
#                           /Users/rayanjoseph/.conda/pkgs
#        envs directories : /Users/rayanjoseph/anaconda3/envs
#                           /Users/rayanjoseph/.conda/envs
#                platform : osx-arm64
#              user-agent : conda/23.7.4 requests/2.31.0 CPython/3.11.5 Darwin/23.0.0 OSX/14.0 aau/0.4.2 c/PCKwqwpv1Hs7rIWxMDSQuA s/fYHNsbaIKihI3PEHDb5aOw e/Y848-1OmEqhFMFIskBvHGg
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False

# %%
conda install pytorch torchvision -c pytorch
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-arm64::notebook-shim==0.2.3=py311hca03da5_0
#   - defaults/osx-arm64::nbconvert==7.10.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyterlab_server==2.25.1=py311hca03da5_0
#   - defaults/osx-arm64::notebook==7.0.6=py311hca03da5_0
#   - defaults/noarch::bleach==4.1.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::jupyterlab==4.0.8=py311hca03da5_0
#   - defaults/osx-arm64::ipykernel==6.25.0=py311hb6e6a13_0
#   - defaults/osx-arm64::jupyter_server==2.10.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyter-lsp==2.2.0=py311hca03da5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/rayanjoseph/anaconda3/envs/trainings
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2024.2.2           |  py311hca03da5_0         161 KB
#     filelock-3.13.1            |  py311hca03da5_0          25 KB
#     libdeflate-1.17            |       h80987f9_1          55 KB
#     libjpeg-turbo-2.0.0        |       h1a28f6b_0         386 KB
#     numpy-1.26.3               |  py311he598dae_0          11 KB
#     numpy-base-1.26.3          |  py311hfbfe69c_0         6.9 MB
#     openssl-3.0.13             |       h1a28f6b_0         5.0 MB
#     pillow-10.2.0              |  py311h80987f9_0         855 KB
#     pytorch-2.2.0              |         py3.11_0        55.5 MB  pytorch
#     sympy-1.12                 |  py311hca03da5_0        14.4 MB
#     torchvision-0.17.0         |        py311_cpu         6.8 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        90.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   filelock           pkgs/main/osx-arm64::filelock-3.13.1-py311hca03da5_0
#   freetype           pkgs/main/osx-arm64::freetype-2.12.1-h1192e45_0
#   gmp                pkgs/main/osx-arm64::gmp-6.2.1-hc377ac9_3
#   gmpy2              pkgs/main/osx-arm64::gmpy2-2.1.2-py311h40f64dc_0
#   jpeg               pkgs/main/osx-arm64::jpeg-9e-h80987f9_1
#   lcms2              pkgs/main/osx-arm64::lcms2-2.12-hba8e193_0
#   lerc               pkgs/main/osx-arm64::lerc-3.0-hc377ac9_0
#   libdeflate         pkgs/main/osx-arm64::libdeflate-1.17-h80987f9_1
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libjpeg-turbo      pkgs/main/osx-arm64::libjpeg-turbo-2.0.0-h1a28f6b_0
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.21-h269037a_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.5.1-h313beb8_0
#   libwebp-base       pkgs/main/osx-arm64::libwebp-base-1.3.2-h80987f9_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-14.0.6-hc6e5704_0
#   lz4-c              pkgs/main/osx-arm64::lz4-c-1.9.4-h313beb8_0
#   mpc                pkgs/main/osx-arm64::mpc-1.1.0-h8c48613_1
#   mpfr               pkgs/main/osx-arm64::mpfr-4.0.2-h695f6f0_1
#   mpmath             pkgs/main/osx-arm64::mpmath-1.3.0-py311hca03da5_0
#   networkx           pkgs/main/osx-arm64::networkx-3.1-py311hca03da5_0
#   numpy              pkgs/main/osx-arm64::numpy-1.26.3-py311he598dae_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.26.3-py311hfbfe69c_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.3.0-h7a6adac_2
#   packaging          pkgs/main/osx-arm64::packaging-23.1-py311hca03da5_0
#   pillow             pkgs/main/osx-arm64::pillow-10.2.0-py311h80987f9_0
#   pytorch            pytorch/osx-arm64::pytorch-2.2.0-py3.11_0
#   sympy              pkgs/main/osx-arm64::sympy-1.12-py311hca03da5_0
#   torchvision        pytorch/osx-arm64::torchvision-0.17.0-py311_cpu
#   zstd               pkgs/main/osx-arm64::zstd-1.5.5-hd90d995_0
#
# The following packages will be UPDATED:
#
#   certifi                        2023.11.17-py311hca03da5_0 --> 2024.2.2-py311hca03da5_0
#   openssl                                 3.0.12-h1a28f6b_0 --> 3.0.13-h1a28f6b_0
#
#
#
# Downloading and Extracting Packages
# filelock-3.13.1      | 25 KB     |                                       |   0%
# libjpeg-turbo-2.0.0  | 386 KB    |                                       |   0%
#
# torchvision-0.17.0   | 6.8 MB    |                                       |   0%
#
#
# certifi-2024.2.2     | 161 KB    |                                       |   0%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    |                                       |   0%
#
#
#
#
# sympy-1.12           | 14.4 MB   |                                       |   0%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    |                                       |   0%
#
#
#
#
#
#
# numpy-1.26.3         | 11 KB     |                                       |   0%
#
#
#
#
#
#
#
# libdeflate-1.17      | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 855 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# filelock-3.13.1      | 25 KB     | #######################3              |  63%
# libjpeg-turbo-2.0.0  | 386 KB    | #5                                    |   4%
#
#
# filelock-3.13.1      | 25 KB     | ##################################### | 100%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    |                                       |   0%
#
# torchvision-0.17.0   | 6.8 MB    |                                       |   0%
#
#
#
#
# sympy-1.12           | 14.4 MB   |                                       |   0%
#
#
# certifi-2024.2.2     | 161 KB    | ##################################### | 100%
# libjpeg-turbo-2.0.0  | 386 KB    | ##################################### | 100%
# libjpeg-turbo-2.0.0  | 386 KB    | ##################################### | 100%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | 1                                     |   0%
#
#
#
#
#
#
# numpy-1.26.3         | 11 KB     | ##################################### | 100%
#
#
#
#
#
#
# numpy-1.26.3         | 11 KB     | ##################################### | 100%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    | #####3                                |  15%
#
# torchvision-0.17.0   | 6.8 MB    | ###8                                  |  10%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
# libdeflate-1.17      | 55 KB     | ##########7                           |  29%
#
#
#
#
#
#
#
# libdeflate-1.17      | 55 KB     | ##################################### | 100%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | #########2                            |  25%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    | ###############2                      |  41%
#
# torchvision-0.17.0   | 6.8 MB    | #########                             |  25%
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 855 KB    | 6                                     |   2%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ####9                                 |  13%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | #############3                        |  36%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    | ###########################8          |  75%
#
# torchvision-0.17.0   | 6.8 MB    | ##################3                   |  50%
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 855 KB    | ###################################3  |  95%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ###########                           |  30%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | #######################9              |  65%
#
# torchvision-0.17.0   | 6.8 MB    | ##############################        |  81%
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 855 KB    | ##################################### | 100%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ################4                     |  45%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | ################################2     |  87%
#
#
#
#
# sympy-1.12           | 14.4 MB   | #####################1                |  57%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   |                                       |   0%
#
#
#
#
#
# openssl-3.0.13       | 5.0 MB    | ##################################### | 100%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | #                                     |   3%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | #####6                                |  15%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    | ##################################### | 100%
#
#
#
# numpy-base-1.26.3    | 6.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ##############3                       |  39%
#
# torchvision-0.17.0   | 6.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ########################3             |  66%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ##################################### | 100%
#
#
#
#
# sympy-1.12           | 14.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ################################1     |  87%
#
#
#
#
#
#
#
#
#
# pytorch-2.2.0        | 55.5 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7409, 0.0155, 0.7800],
#         [0.0162, 0.9301, 0.2049],
#         [0.7203, 0.9690, 0.3069],
#         [0.6150, 0.5057, 0.7462],
#         [0.8128, 0.8992, 0.9506]])

# %%
python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('I love you'))"
# Out:
#   Cell In[4], line 1
#     python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('I love you'))"
#               ^
# SyntaxError: invalid syntax

# %%
import platform

# %%
platform.platform()
# Out:
# 'macOS-14.0-arm64-arm-64bit'
